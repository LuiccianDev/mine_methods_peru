# %%
import pandas as pd

df = pd.read_csv("../Data/Mineral ores round the world.csv")

# Estraccionde datas de solod e peru
df_peru = df[df["country"] == "Peru"].copy()

# solo elgir la columans necesarias
cols = [
    "site_name",
    "latitude",
    "longitude",
    "state",
    "com_type",
    "commod1",
    "dep_type",
    "prod_size",
    "dev_stat",
    "ore",
    "work_type",
    "hrock_type",
    "arock_type",
]
df_peru = df_peru[cols]

# Guardar el nuevo dataset
df_peru.to_csv("../Data/df_peru_cleaned.csv", index=False)
